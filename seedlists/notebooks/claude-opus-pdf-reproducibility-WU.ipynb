# %% [markdown]
# # Extraction of plant species names from seedlists in PDF format

# %%
import json
import pandas as pd
import re
import os
import anthropic
from pypdf import PdfReader

# %%
# Enter API key
client = anthropic.Anthropic(
    api_key="",
)

# %%
# Don't truncate display
pd.set_option('display.max_colwidth', None) 
pd.set_option('display.max_rows', None)

# %%
# Input seedlist file path
input_path = "../data/raw/WU/WU_7.pdf"

# Output path to store extracted species names in csv format
output_path = '../data/processed/claude/pdf'

# Create output directory if it doesn't exist
if not os.path.exists(output_path):
    os.makedirs(output_path)

# %%
# Extract filename
filename_with_extension = input_path.split('/')[-1]
filename = filename_with_extension.split('.')[0]

# %%
# Instructions for Claude 
instructions = '''
You are an expert botanist with deep knowledge of Latin names in binomial nomenclature of plant species.
You have knowledge of plant family names, subspecies, varieties and forms.
 
The species name in binomial nomenclature consists of two parts: 
the genus name starting with a capital letter, 
followed by the epithet name which normally starts with a small letter. 

This is often followed by a subspecies name (starting with "subsp. " or "ssp. "), 
or variety name (starting with "var."), or form (starting with "f.") and the author name(s). 
Sometimes this is followed by a synonym (starting with a syn.).

Some species names are also followed by a cultivar name (almost always within with single quotation marks 
or with the abbreviation "CV" if the cultivar has no formal name. 

The author name is often simply "L.", for "Linnaeus". For other authors it is often an abbreviation 
describing the author name.

Thus the species name consists of the genus, epithet, subspecies name (if present), variety name (if present), 
form name (if present), cultivar name (if present), author name(s) (if present) and synonym (if present).  
                                                         
You are given the text from a page from a seedlist of plants from a botanical garden. 
Determine if there are any Latin names of plant species present in this text. 
Find each and every plant species entry present in the text.
Do not skip or miss any entry.
 
If any plant species names are present in this text, find, for each plant species present in the text, 
the species name in Latin, consisting of the genus, epithet, subspecies name (if present), 
variety name (if present), form name (if present), cultivar name (if present), author name(s) (if present), 
and synonym (if present).  

Return the result for each plant species in valid JSON object format, with the single key "species".
Provide the complete results as a list of valid JSON objects.
If there is no information about plant species on this page, print an empty list, like this: []
Print only the complete list of valid JSON objects, and no other code, text, or explanation.
'''

# %%
# Read seedlist text
reader = PdfReader(input_path)
seedlist_text = reader.pages[0].extract_text()

# %%
# Text of seedlist
seedlist_text
# Out:
# 'Bestell - \nNr. /  \nOrder  \nNr. Name  \n  Herkunft u. Art \nder Diasporen /  \norigin  and type  of \ndiaspores          IPEN  Aufsammlungs -\ndaten / \ncollecting data  \n \n Asteraceae (cont.)  \n30  Centaurea jacea L.        WS     AT-0-WU-0030521    42 \n31  -- jacea subsp . angustifolia (DC.) Gremli     WS     AT-0-WU-0031475    117 \n32  -- pseudophrygia C. A. Mey.       WS     AT-0-WU-0027271    125 \n33  -- scabiosa L.         WS     AT-0-WU-0030447    37 \n34  -- scabiosa L.         WS     AT-0-WU-0031441    95 \n35  Cirsium canum (L.) All.        WS     AT-0-WU-0031471    121 \n36  -- eriophorum (L.) Scop.        WKS     AT-0-WU-0007975    125 \n37  -- erisithales (Jacq.) Scop.        WS     AT-0-WU-0031498    114 \n38  -- pannonicum (L. f.) Link        WS     AT-0-WU-0030486    37 \n39  -- spinosissimum (L.) Scop.        WS     AT-0-WU-0030577    53 \n40  Crepis pyrenaica (L.) Greuter       WS     AT-0-WU-0030527    45 \n41  -- pyrenaica (L.) Greuter        WS     AT-0-WU-0031494    114 \n42  Cyanus  segetum Hill        WS     AT-0-WU-0031457    99 \n43  Echinops ritro subsp . ruthenicus (M. Bieb.) Nyman     WS     AT-0-WU-0030642    70 \n44  -- ritro subsp . ruthenicus (M. Bieb.) Nyman     WKS     AT-0-WU-0031014    125 \n45  Erigeron acris L.         WS     AT-0-WU-0030619    65 \n46  -- glabellus Nutt.        KS     XX-0-WU-0022433     125 \n47  Eupatorium cannabinum L.        KS     XX-0-WU-0025821     125 \n48  Filago arvensis L.       WS     AT-0-WU-0031534    125 \n49  -- vulgaris Lam.         WS     AT-0-WU-0031367    111 \n50  Galatella cana (Waldst. & Kit.) Nees      WS     AT-0-WU-0030647    75 \n51  -- linosyris (L.) Rchb. f.        WS     AT-0-WU-0030644    72 \n52  Gnaphalium sylvaticum L.        WS     AT-0-WU-0029392    16 \n53  Helenium aromaticum (Hook.) L. H. Bailey     KS     XX-0-WU-0031245     125 \n54  Hieracium prenanthoides Vill.       KS     XX-0-WU-0030679     125 \n55  -- umbellatum L.        KS     XX-0-WU-0002204     77 \n56  -- umbellatum L.        WKS     AT-0-WU-0008873    125 \n57  -- velutinum Hegetschw.        WKS     CH-0-WU-0009851    125 \n58  -- villosum Jacq.         WKS     FR-0-WU-0008195    125 \n59  Homogyne sylvestris Cass.        WS     AT-0-WU-0029414    18 \n60  Inula ensifolia L.        WS     AT-0-WU-0030639    70 \n61  -- oculus -christi L.        WS     AT-0-WU-0030435    36 \n62  Jurinea mollis (L.) Rchb.        WS     AT-0-WU-0031346    91 \n63  Klasea quinquefolia (Willd.) Greuter & Wagenitz     KS     XX-0-WU-0019038     125 \n64  Leontodon incanus (L.) Schrank      WS     AT-0-WU-0027771    1 \n65  -- pyrenaicus  \n    subsp. helveticus  (Mérat) Finch & P. D. Sell     WKS     FR-0-WU-0009648    125 \n66  Leucanthemopsis alpina (L.) Heywood     WS     AT-0-WU-0030566    53 \n67  Liatris cylindracea Michx.        WKS     NZ-0-MO-2015- 0204   125 \n68  Onopordum acanthium L.        WS    AT-0-WU-0031459    96 \n69  Prenanthes purpurea L.        WKS     CH-0-WU-0007600    125 \n70  -- purpurea L.         WS     AT-0-WU-0031502    114 \n71  Pseudognaphalium luteoalbum (L.) Hilliard & B. L. Burtt    KS     XX-0-WU-0031535     125 '

# %%
# Create prompt
prompt = instructions + ' Seedlist text: ' + seedlist_text

# %%
# Set up function for API call
def get_completion(prompt):
    message = client.messages.create(
        model="claude-3-opus-20240229",
        max_tokens=4096,
        temperature=0.0,
        messages=[
            {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text

# %%
# %%time

# Number of runs
num_runs = 3

# List to store result dataframes
list_df = []

for run in range(num_runs):

    print(f'Starting run {run} ...')
    
    # Call the API
    response = get_completion(prompt)

    # Post-processing
    result = re.search(r'\[.*\]', response, re.DOTALL)
    json_data_string = result.group()

    # Read JSON data into dataframe
    data = json.loads(json_data_string)

    # Output dataframe from this run
    df = pd.DataFrame(data)

    # Save dataframe to csv file
    df.to_csv(f'{output_path}/{filename}_run_{run}.csv', index=False)

    # Append to list of dataframes
    list_df.append(df)
    
    print(f'Finished run {run}.')
# Out:
# Starting run 0 ...
# Finished run 0.
# Starting run 1 ...
# Finished run 1.
# Starting run 2 ...
# Finished run 2.
# CPU times: user 32.3 ms, sys: 4.41 ms, total: 36.7 ms
# Wall time: 1min 54s

# %%
# Concatenate the dataframes from different runs
df_concat = pd.concat([df.T for df in list_df], ignore_index=True).T

# %%
# Display the results from all runs
df_concat
# Out:
#                                                                     0  \
# 0                                                  Centaurea jacea L.
# 1                    Centaurea jacea subsp. angustifolia (DC.) Gremli
# 2                                  Centaurea pseudophrygia C. A. Mey.
# 3                                               Centaurea scabiosa L.
# 4                                               Centaurea scabiosa L.
# 5                                             Cirsium canum (L.) All.
# 6                                       Cirsium eriophorum (L.) Scop.
# 7                                   Cirsium erisithales (Jacq.) Scop.
# 8                                     Cirsium pannonicum (L. f.) Link
# 9                                    Cirsium spinosissimum (L.) Scop.
# 10                                      Crepis pyrenaica (L.) Greuter
# 11                                      Crepis pyrenaica (L.) Greuter
# 12                                                Cyanus segetum Hill
# 13                  Echinops ritro subsp. ruthenicus (M. Bieb.) Nyman
# 14                  Echinops ritro subsp. ruthenicus (M. Bieb.) Nyman
# 15                                                  Erigeron acris L.
# 16                                           Erigeron glabellus Nutt.
# 17                                           Eupatorium cannabinum L.
# 18                                                 Filago arvensis L.
# 19                                               Filago vulgaris Lam.
# 20                               Galatella cana (Waldst. & Kit.) Nees
# 21                                  Galatella linosyris (L.) Rchb. f.
# 22                                           Gnaphalium sylvaticum L.
# 23                           Helenium aromaticum (Hook.) L. H. Bailey
# 24                                      Hieracium prenanthoides Vill.
# 25                                            Hieracium umbellatum L.
# 26                                            Hieracium umbellatum L.
# 27                                     Hieracium velutinum Hegetschw.
# 28                                           Hieracium villosum Jacq.
# 29                                          Homogyne sylvestris Cass.
# 30                                                 Inula ensifolia L.
# 31                                            Inula oculus-christi L.
# 32                                          Jurinea mollis (L.) Rchb.
# 33                    Klasea quinquefolia (Willd.) Greuter & Wagenitz
# 34                                     Leontodon incanus (L.) Schrank
# 35  Leontodon pyrenaicus subsp. helveticus (Mérat) Finch & P. D. Sell
# 36                                Leucanthemopsis alpina (L.) Heywood
# 37                                         Liatris cylindracea Michx.
# 38                                             Onopordum acanthium L.
# 39                                             Prenanthes purpurea L.
# 40                                             Prenanthes purpurea L.
# 41            Pseudognaphalium luteoalbum (L.) Hilliard & B. L. Burtt
#
#                                                                     1  \
# 0                                                  Centaurea jacea L.
# 1                    Centaurea jacea subsp. angustifolia (DC.) Gremli
# 2                                  Centaurea pseudophrygia C. A. Mey.
# 3                                               Centaurea scabiosa L.
# 4                                               Centaurea scabiosa L.
# 5                                             Cirsium canum (L.) All.
# 6                                       Cirsium eriophorum (L.) Scop.
# 7                                   Cirsium erisithales (Jacq.) Scop.
# 8                                     Cirsium pannonicum (L. f.) Link
# 9                                    Cirsium spinosissimum (L.) Scop.
# 10                                      Crepis pyrenaica (L.) Greuter
# 11                                      Crepis pyrenaica (L.) Greuter
# 12                                                Cyanus segetum Hill
# 13                  Echinops ritro subsp. ruthenicus (M. Bieb.) Nyman
# 14                  Echinops ritro subsp. ruthenicus (M. Bieb.) Nyman
# 15                                                  Erigeron acris L.
# 16                                           Erigeron glabellus Nutt.
# 17                                           Eupatorium cannabinum L.
# 18                                                 Filago arvensis L.
# 19                                               Filago vulgaris Lam.
# 20                               Galatella cana (Waldst. & Kit.) Nees
# 21                                  Galatella linosyris (L.) Rchb. f.
# 22                                           Gnaphalium sylvaticum L.
# 23                           Helenium aromaticum (Hook.) L. H. Bailey
# 24                                      Hieracium prenanthoides Vill.
# 25                                            Hieracium umbellatum L.
# 26                                            Hieracium umbellatum L.
# 27                                     Hieracium velutinum Hegetschw.
# 28                                           Hieracium villosum Jacq.
# 29                                          Homogyne sylvestris Cass.
# 30                                                 Inula ensifolia L.
# 31                                            Inula oculus-christi L.
# 32                                          Jurinea mollis (L.) Rchb.
# 33                    Klasea quinquefolia (Willd.) Greuter & Wagenitz
# 34                                     Leontodon incanus (L.) Schrank
# 35  Leontodon pyrenaicus subsp. helveticus (Mérat) Finch & P. D. Sell
# 36                                Leucanthemopsis alpina (L.) Heywood
# 37                                         Liatris cylindracea Michx.
# 38                                             Onopordum acanthium L.
# 39                                             Prenanthes purpurea L.
# 40                                             Prenanthes purpurea L.
# 41            Pseudognaphalium luteoalbum (L.) Hilliard & B. L. Burtt
#
#                                                                     2
# 0                                                  Centaurea jacea L.
# 1                    Centaurea jacea subsp. angustifolia (DC.) Gremli
# 2                                  Centaurea pseudophrygia C. A. Mey.
# 3                                               Centaurea scabiosa L.
# 4                                               Centaurea scabiosa L.
# 5                                             Cirsium canum (L.) All.
# 6                                       Cirsium eriophorum (L.) Scop.
# 7                                   Cirsium erisithales (Jacq.) Scop.
# 8                                     Cirsium pannonicum (L. f.) Link
# 9                                    Cirsium spinosissimum (L.) Scop.
# 10                                      Crepis pyrenaica (L.) Greuter
# 11                                      Crepis pyrenaica (L.) Greuter
# 12                                                Cyanus segetum Hill
# 13                  Echinops ritro subsp. ruthenicus (M. Bieb.) Nyman
# 14                  Echinops ritro subsp. ruthenicus (M. Bieb.) Nyman
# 15                                                  Erigeron acris L.
# 16                                           Erigeron glabellus Nutt.
# 17                                           Eupatorium cannabinum L.
# 18                                                 Filago arvensis L.
# 19                                               Filago vulgaris Lam.
# 20                               Galatella cana (Waldst. & Kit.) Nees
# 21                                  Galatella linosyris (L.) Rchb. f.
# 22                                           Gnaphalium sylvaticum L.
# 23                           Helenium aromaticum (Hook.) L. H. Bailey
# 24                                      Hieracium prenanthoides Vill.
# 25                                            Hieracium umbellatum L.
# 26                                            Hieracium umbellatum L.
# 27                                     Hieracium velutinum Hegetschw.
# 28                                           Hieracium villosum Jacq.
# 29                                          Homogyne sylvestris Cass.
# 30                                                 Inula ensifolia L.
# 31                                            Inula oculus-christi L.
# 32                                          Jurinea mollis (L.) Rchb.
# 33                    Klasea quinquefolia (Willd.) Greuter & Wagenitz
# 34                                     Leontodon incanus (L.) Schrank
# 35  Leontodon pyrenaicus subsp. helveticus (Mérat) Finch & P. D. Sell
# 36                                Leucanthemopsis alpina (L.) Heywood
# 37                                         Liatris cylindracea Michx.
# 38                                             Onopordum acanthium L.
# 39                                             Prenanthes purpurea L.
# 40                                             Prenanthes purpurea L.
# 41            Pseudognaphalium luteoalbum (L.) Hilliard & B. L. Burtt
